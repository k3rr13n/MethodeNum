# %% [markdown]
# # TP2 Complexité

# %% [markdown]
# En informatique, on s'interesse à la complexité des algorithmes lorsque l'on veut :
#
# - Evaluer l'efficacité d'un algo
#
# - Comparer deux algo indéependamment de l'environnement (machine, système, compilateur, . . .). On évalue alors le nombre d'opérations éléementaires en fonction de la taille des données, de la nature des données.
#
# Notations :
#
# - $n$ : taille des données,
#
# - $T(n)$ : nombre d'opérations élémentaires dans le pire des cas. Si on a très rarement l'expression de $T(n)$ en fonction de $n$, on arrive à comparer $T(n)$ à des suites "de référence".

# %% [markdown]
# ## Exercice 1 - Premier exemple : un algorithme de calcul

# %% [markdown]
# On veut évaluer la complexité $T(n)$ du premier algorithme du TP1.

# %%
def a(n):
	res=0.25
	for i in range(n):
		res=2*res+1
	return res

# %% [markdown]
# Expliquez chacune des étapes ci-dessous puis en déduire comment trouver la complexité d'un algorithme.

# %%
#ETAPE 1

def a(n):
	nbiter=0
	res=0.25
	for i in range(n):
		res=2*res+1
		nbiter+=1
	return (res,nbiter)

def T(n):
	return a(n)[1]

# %% [markdown]
# Réponse :

# %%
#ETAPE 2

import matplotlib.pyplot as plt

xn=range(30)
tn=[T(n) for n in xn]
plt.plot(xn,tn,'db-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 import matplotlib.pyplot as plt
#       5 xn=range(30)
# ----> 6 tn=[T(n) for n in xn]
#       7 plt.plot(xn,tn,'db-')
#       8 plt.show()
#
# NameError: name 'T' is not defined

# %% [markdown]
# Réponse :

# %%
#ETAPE 3 

xn=range(1,30)
qn=[T(n)*1.0/n for n in xn]
plt.plot(xn,qn,'db-')
plt.show()

# %% [markdown]
# Réponse :

# %% [markdown]
# ## Exercice 2 - Un autre algorithme de calcul

# %% [markdown]
# On veut évaluer la complexité $T(n)$ de l'algorithme suivant :

# %%
def A(n):
    nbiter=0
    nbi=0
    res=0
    for k in range(n):
        if (n%2==0):
            for i in range(n):
                res=res+i
                nbi+=1
        else :
            res =3* res +1
        nbiter+=1
    return (res,nbiter+nbi)

def t(n):
	return A(n)[1]

import matplotlib.pyplot as plt

xn=range(50)
tn=[t(n) for n in xn]
plt.plot(xn,tn,'db-')
plt.show()

# %% [markdown]
# 1. Ajouter un compteur permettant de compter le nombre d'opérations élémentaires.
# 2. Construire la liste des $T(n)$ pour $n$ variant de 0 à 50.
# 3. Représenter la suite $T(n)$ et conjecturer son com-
# portement
# 4. Validez votre conjecture.

# %%
xn=range(1,30)
qn=[t(n)*1.0/(n**2) for n in xn]
plt.plot(xn,qn,'db-')
plt.show()

# %% [markdown]
# Réponse :

# %% [markdown]
# ## Exercice 3 - Recherche séquentielle dans une liste

# %% [markdown]
# On veut évaluer la complexité $T(n)$ de l'algorithme de recherche séquentielle dans un tableau
# (où $n$ est la taille du tableau).

# %% [markdown]
# 1. Terminer l'écriture de la
# fonction Recherche (et
# testez la !!)
# 2. Ajouter un compteur
# permettant de compter
# le nombre d'opérations
# élémentaires.
# 3. Construire la liste des
# $T(n)$ pour $n$ variant
# de 0 à 100000 avec
# un pas de 1000. (On
# recherchera un nombre
# aléatoire choisi entre 1 et 1000)
# 4. Représenter la suite
# $T(n)$ et conjecturer son
# comportement

# %%
from random import *

def tab(n):
    return [ randint(1 ,1000) for i in range(n)]

# renvoie True si x est dans tab, False sinon

def Recherche(x,tab):
909, 78, 262, 937, 616, 375, 470, 340, 571, 580, 681, 547, 785, 968, 158, 403, 688, 229, 250, 578, 741, 4, 825, 11, 170, 78, 310, 411, 88, 745, 883, 763, 725, 707, 971, 201, 465, 458, 791, 689, 551, 50, 628, 797, 835, 387, 433, 689, 567, 263, 149, 465, 187, 56, 330, 907, 351, 509, 225, 291, 268, 204, 474, 528, 625, 137, 725, 920, 326, 770, 140, 240, 483, 390, 813, 978, 441, 612, 32, 871, 289, 18, 218, 980, 301, 746, 212, 618, 575, 101, 953, 728, 211, 308, 113, 917, 922, 342, 183, 359, 723, 418, 693, 667, 847, 539, 115, 568, 830, 398, 784, 135, 286, 230, 695, 290, 373, 191, 976, 304, 189, 471, 379, 549, 186, 854, 788, 321, 771, 420, 45, 53, 317, 816, 539, 507, 948, 975, 713, 4, 504, 21, 595, 763, 904, 489, 691, 625, 167, 707, 756, 59, 605, 21, 406, 36, 369, 542, 248, 191, 539, 925, 879, 108, 303, 518, 678, 614, 587, 424, 870, 787, 276, 488, 451, 84, 376, 737, 9, 494, 733, 648, 390, 135, 424, 892, 995, 439, 17, 907, 728, 240, 570, 194, 31, 636, 513, 254, 367, 39, 475, 975, 129, 485, 221, 757, 793, 810, 73, 350, 137, 95, 806, 365, 793, 201, 195, 922, 374, 850, 456, 922, 502, 893, 385, 61, 1, 392, 976, 548, 767, 937, 860, 593, 862, 376, 42, 538, 228, 142, 996, 586, 511, 700, 211, 117, 597, 129, 600, 145, 805, 141, 597, 222, 797, 115, 359, 729, 494, 839, 771, 233, 920, 868, 973, 626, 597, 995, 116, 284, 581, 118, 559, 267, 423, 967, 343, 25, 465, 178, 506, 280, 835, 851, 253, 473, 627, 858, 242, 354, 134, 859, 644, 211, 601, 15, 844, 453, 972, 364, 846, 986, 77, 190, 266, 254, 3, 351, 134, 425, 173, 477, 542, 668, 560, 106, 9, 345, 533, 20, 604, 601, 963, 456, 104, 119, 23, 502, 139, 144, 123, 900, 288, 879, 91, 674, 746, 458, 444, 162, 752, 71, 359, 649, 626, 407, 330, 824, 690,  ...

# %% [markdown]
# Réponse :

# %% [markdown]
# ## Exercice 4 - Recherche dichotomique dans un tableau trié
# On veut évaluer la complexité $T(n)$ de l'algorithme de recherche dichotomique dans un
# tableau trié (où $n$ est la taille du tableau).

# %% [markdown]
# 1. Terminer l'écriture de la fonction RechercheDicho (et testez la !!)
# 2. Ajouter un compteur permettant de compter le nombre d'opérations élémentaires.
# 3. Construire la liste des $T(n)$ pour $n$ variant de 0 à 1000. (On recherchera un nombre
# aléatoire choisi entre 1 et 1000)
# 4. Représenter la suite $T(n)$ et conjecturer son comportement
# 5. Valider votre conjecture.

# %%
from random import *
from math import *

def tab(n):
    temp =[randint (1,1000) for i in range(n)]
    temp.sort()
    return temp

# RechercheDicho renvoie l'indice de x dans tab
# ou -1 si x n'est pas dans tab

def RechercheDicho(x,tab):
    pass

print(RechercheDicho(randint(1,1000),tab(1000)))

# %% [markdown]
# Réponse :

# %% [markdown]
# ## Exercice 5 - Des algorithmes de tri

# %% [markdown]
# Evaluer la complexité $T(n)$ des différents algorithmes de tri que vous avez vus (où $n$
# est la taille du tableau). Quel est le plus performant ? le moins performant ?
#
# - Tri par sélection
#
# - Tri à bulles
#
# - Tri par insertion
